# %%
import pandas as pd

# %%
numbers = [12,53,57]
pd.Series(numbers)
# Out:
# 0    12
# 1    53
# 2    57
# dtype: int64

# %%
data = {'one' : [1.2, 2, 3, 4],
        'two' : [4, 3, 2.5, 1]}
pd.DataFrame(data)
# Out:
#    one  two
# 0  1.2  4.0
# 1  2.0  3.0
# 2  3.0  2.5
# 3  4.0  1.0

# %%
data = {'one' : [1.2, 2, 3, 4],
        'two' : [4, 3, 2.5, 1]}
dataframe  = pd.DataFrame(data)

# %%
dataframe.head(2)
# Out:
#    one  two
# 0  1.2  4.0
# 1  2.0  3.0

# %%
dataframe.tail(2)
# Out:
#    one  two
# 2  3.0  2.5
# 3  4.0  1.0

# %%
dataframe.T
# Out:
#        0    1    2    3
# one  1.2  2.0  3.0  4.0
# two  4.0  3.0  2.5  1.0

# %%
dataframe_columntwo = dataframe['one']

# %%
dataframe_columntwo.head()
# Out:
# 0    1.2
# 1    2.0
# 2    3.0
# 3    4.0
# Name: one, dtype: float64

# %%
dataframe.iloc[1]
# Out:
# one    2.0
# two    3.0
# Name: 1, dtype: float64

# %%
dataframe['graison'] = 100

# %%
dataframe.head()
# Out:
#    one  two  graison
# 0  1.2  4.0      100
# 1  2.0  3.0      100
# 2  3.0  2.5      100
# 3  4.0  1.0      100

# %%
census_data = pd.read_csv('../data/2016_census_data.csv')

# %%
census_data.head()
# Out:
#          geoid                                        name  total_population  \
# 0  34003001000  Census Tract 10, Bergen County, New Jersey              6767
# 1  34003002100  Census Tract 21, Bergen County, New Jersey              1522
# 2  34003002200  Census Tract 22, Bergen County, New Jersey              5389
# 3  34003002300  Census Tract 23, Bergen County, New Jersey              5828
# 4  34003003100  Census Tract 31, Bergen County, New Jersey              4946
#
#    median_income  median_home_value  educational_attainment  white_alone  \
# 0       151641.0           680000.0                  3045.0       5667.0
# 1       114545.0          2000001.0                   836.0        788.0
# 2        90647.0           453800.0                  1791.0       3481.0
# 3       112031.0           610000.0                  2363.0       3595.0
# 4        76906.0           301900.0                  1588.0       1803.0
#
# ...

# %%
census_data.tail()
# Out:
#             geoid                                             name  \
# 4695  42103950701  Census Tract 9507.01, Pike County, Pennsylvania
# 4696  42103950702  Census Tract 9507.02, Pike County, Pennsylvania
# 4697  42103950801  Census Tract 9508.01, Pike County, Pennsylvania
# 4698  42103950802  Census Tract 9508.02, Pike County, Pennsylvania
# 4699  42103950900     Census Tract 9509, Pike County, Pennsylvania
#
#       total_population  median_income  median_home_value  \
# 4695              4107        61726.0           155800.0
# 4696              3119        59239.0           151100.0
# 4697              4403        55530.0           120000.0
# 4698              6004        50724.0           146700.0
# 4699              4184        49453.0           146100.0
#
#       educational_attainment  white_alone  black_alone  native  asian  \
# 4695                   537.0       3665.0         12.0     0.0   67.0
# 4696                   405.0       2908.0         44.0     0.0   60.0
# ...

# %%
census_data.T
# Out:
#                                                                         0     \
# geoid                                                            34003001000
# name                              Census Tract 10, Bergen County, New Jersey
# total_population                                                        6767
# median_income                                                         151641
# median_home_value                                                     680000
# educational_attainment                                                  3045
# white_alone                                                             5667
# black_alone                                                               75
# native                                                                     0
# asian                                                                    759
# native_hawaiian_pacific_islander                                           0
# ...

# %%
census_data.columns
# Out:
# Index(['geoid', 'name', 'total_population', 'median_income',
#        'median_home_value', 'educational_attainment', 'white_alone',
#        'black_alone', 'native', 'asian', 'native_hawaiian_pacific_islander',
#        'some_other_race_alone', 'two_or_more', 'hispanic_or_latino'],
#       dtype='object')

# %%
census_data.dtypes
# Out:
# geoid                                 int64
# name                                 object
# total_population                      int64
# median_income                       float64
# median_home_value                   float64
# educational_attainment              float64
# white_alone                         float64
# black_alone                         float64
# native                              float64
# asian                               float64
# native_hawaiian_pacific_islander    float64
# some_other_race_alone               float64
# two_or_more                         float64
# hispanic_or_latino                  float64
# dtype: object

# %%
len(census_data.columns)
# Out:
# 14

# %%
census_data['hispanic_or_latino']
# Out:
# 0        134.0
# 1        122.0
# 2        504.0
# 3        448.0
# 4       1365.0
# 5       1564.0
# 6       1522.0
# 7        589.0
# 8        771.0
# 9       1493.0
# 10      1301.0
# 11      2210.0
# 12      1564.0
# 13      1827.0
# 14      1295.0
# 15       600.0
# 16      3678.0
# 17       362.0
# 18        72.0
# 19       785.0
# 20       522.0
# 21        76.0
# 22       816.0
# 23       805.0
# 24      1522.0
# 25      1528.0
# 26      1725.0
# 27      1083.0
# 28      1651.0
# 29      1824.0
#          ...
# 4670     736.0
# 4671     557.0
# 4672     206.0
# 4673     449.0
# 4674     166.0
# 4675     182.0
# 4676     377.0
# 4677     330.0
# 4678     496.0
# 4679     176.0
# 4680      38.0
# 4681     417.0
# 4682     254.0
# 4683     129.0
# 4684     127.0
# 4685     353.0
# 4686      56.0
# 4687      27.0
# 4688       0.0
# 4689     221.0
# 4690     483.0
# 4691      59.0
# 4692      52.0
# 4693     195.0
# 4694     437.0
# 4695     337.0
# 4696      88.0
# ...

# %%
columns  = ['hispanic_or_latino', 'median_income']

# %%
census_data['proportion_latino'] = (census_data['hispanic_or_latino']/census_data['total_population'])*100

# %%
census_data.head()
# Out:
#          geoid                                        name  total_population  \
# 0  34003001000  Census Tract 10, Bergen County, New Jersey              6767
# 1  34003002100  Census Tract 21, Bergen County, New Jersey              1522
# 2  34003002200  Census Tract 22, Bergen County, New Jersey              5389
# 3  34003002300  Census Tract 23, Bergen County, New Jersey              5828
# 4  34003003100  Census Tract 31, Bergen County, New Jersey              4946
#
#    median_income  median_home_value  educational_attainment  white_alone  \
# 0       151641.0           680000.0                  3045.0       5667.0
# 1       114545.0          2000001.0                   836.0        788.0
# 2        90647.0           453800.0                  1791.0       3481.0
# 3       112031.0           610000.0                  2363.0       3595.0
# 4        76906.0           301900.0                  1588.0       1803.0
#
# ...
