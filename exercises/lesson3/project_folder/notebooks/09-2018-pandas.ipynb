# %%
import pandas as pd

# %%
charges = pd.read_csv('../data/sh_charge_receipts.csv')

# %%
charges
# Out:
#        CHARGE_FILING_DATE  CP_SEX  \
# 0            Oct/01/1995   Female
# 1            Oct/02/1995   Female
# 2            Oct/02/1995   Female
# 3            Oct/02/1995     Male
# 4            Oct/02/1995   Female
# 5            Oct/02/1995   Female
# 6            Oct/02/1995   Female
# 7            Oct/03/1995   Female
# 8            Oct/03/1995   Female
# 9            Oct/02/1995   Female
# 10           Oct/02/1995   Female
# 11           Oct/02/1995   Female
# 12           Oct/02/1995   Female
# 13           Oct/04/1995   Female
# 14           Oct/05/1995   Female
# 15           Oct/05/1995     Male
# 16           Oct/06/1995     Male
# 17           Oct/06/1995   Female
# 18           Oct/06/1995   Female
# 19           Oct/06/1995   Female
# 20           Oct/06/1995   Female
# 21           Oct/10/1995   Female
# 22           Oct/10/1995   Female
# 23           Oct/10/1995   Female
# 24           Oct/10/1995   Female
# 25           Oct/10/1995   Female
# ...

# %%
charges.head()
# Out:
#   CHARGE_FILING_DATE  CP_SEX                CP_NATIONAL_ORIGIN        CP_DOB  \
# 0       Oct/01/1995   Female  Other National Origin - Obsolete  Oct/21/1969
# 1       Oct/02/1995   Female  Other National Origin - Obsolete  Jan/01/2001
# 2       Oct/02/1995   Female  Other National Origin - Obsolete  Jul/30/1960
# 3       Oct/02/1995     Male  Other National Origin - Obsolete  Jun/02/1957
# 4       Oct/02/1995   Female  Other National Origin - Obsolete  Apr/15/1959
#
#   HISPANIC_CP CP_RACE_STRING  R_NAICS_CODE  \
# 0         NaN              B      311612.0
# 1         NaN              O      541990.0
# 2         NaN              W      722110.0
# 3         NaN              B      422990.0
# 4         NaN              W      523999.0
#
#                                  R_NAICS_DESCRIPTION R_NUMBER_OF_EMPLOYEES  \
# 0                      Meat Processed from Carcasses   201 - 500 Employees
# 1  All Other Professional, Scientific, and Techni...    15 - 100 Employees
# ...

# %%
charges.tail()
# Out:
#        CHARGE_FILING_DATE  CP_SEX  \
# 170017       Jan/31/2014   Female
# 170018       Mar/07/2014   Female
# 170019       May/06/2014     Male
# 170020       Jun/16/2014   Female
# 170021       Apr/07/2015   Female
#
#                                       CP_NATIONAL_ORIGIN        CP_DOB  \
# 170017                Charging Party Declined to Provide  Jun/09/1988
# 170018                   American (U.S.) National Origin  May/02/1990
# 170019                    Other European National Origin  Aug/01/1974
# 170020  Unable to Obtain Information from Charging Party           NaN
# 170021  Unable to Obtain Information from Charging Party           NaN
#
#        HISPANIC_CP CP_RACE_STRING  R_NAICS_CODE  \
# 170017         NaN              N           NaN
# 170018           Y              W           NaN
# 170019         NaN              W      337215.0
# 170020         NaN              N      452111.0
# 170021         NaN              W      621610.0
#
# ...

# %%
len(charges)
# Out:
# 170022
